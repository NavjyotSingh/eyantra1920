# %%
import keras
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import ciso8601
import time
# Out:
# Using TensorFlow backend.

# %%
df1 = pd.read_csv("D:/AIDE/IoT/Home Automation/dataaa.txt",header=None)

# %%
df1['gesture'] = '1111'
df1
# Out:
#                 0    1    2    3    4 gesture
# 0    1.578929e+09  225  342  220  367    1111
# 1    1.578929e+09  236  342  220  363    1111
# 2    1.578929e+09  243  353  230  367    1111
# 3    1.578929e+09  237  355  222  357    1111
# 4    1.578929e+09  250  356  207  358    1111
# 5    1.578929e+09  251  355  216  368    1111
# 6    1.578929e+09  252  350  224  374    1111
# 7    1.578929e+09  247  345  221  357    1111
# 8    1.578929e+09  241  354  215  361    1111
# 9    1.578929e+09  240  345  213  358    1111
# 10   1.578929e+09  247  346  220  357    1111
# 11   1.578929e+09  236  351  217  360    1111
# 12   1.578929e+09  235  350  217  351    1111
# 13   1.578929e+09  246  356  218  359    1111
# 14   1.578929e+09  233  349  208  352    1111
# 15   1.578929e+09  233  343  209  352    1111
# 16   1.578929e+09  235  343  211  353    1111
# 17   1.578929e+09  227  349  210  363    1111
# 18   1.578929e+09  221  345  206  365    1111
# ...

# %%
df1.loc[0:100,'gesture'] = 0
df1.loc[101:200,'gesture'] = 1
df1.loc[201:300,'gesture'] = 2
df1.loc[301:400,'gesture'] = 3
df1.loc[401:500,'gesture'] = 4
df1.loc[501:600,'gesture'] = 5
df1.loc[601:700,'gesture'] = 6
df1.loc[701:801,'gesture'] = 7

# %%
df1.to_csv(r'D:\AIDE\IoT\Home Automation\glove_data.csv', index = None,header=None)

# %%
df2 = pd.read_csv("D:/AIDE/IoT/Home Automation/glove_data.csv",header=None)

# %%
headers = df2.columns
featuresHeaders=[1,2,3,4]


targetHeader = headers[5]

features = df2[featuresHeaders]
target = df2[targetHeader]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
featuresTrain, featuresTest, targetTrain, targetTest = train_test_split(features, target, test_size=0.10, random_state=9)

# %%
import keras 
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
ip = np.array(featuresTrain)
op = np.array(targetTrain)
ipTest = np.array(featuresTest)
opTest = np.array(targetTest)

model = Sequential([
    Dense(12, input_shape=(4,), activation='relu'),
    Dense(10, activation='relu'),
    Dense(8, activation='softmax')
])

# %%
model.compile(Adam(lr=.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(ip, op, batch_size=10,validation_split=0.01, epochs=50, shuffle=True, verbose=2)
# Out:
# Train on 712 samples, validate on 8 samples
# Epoch 1/50
#  - 0s - loss: 12.3679 - acc: 0.1011 - val_loss: 10.4793 - val_acc: 0.2500
# Epoch 2/50
#  - 0s - loss: 12.3446 - acc: 0.1124 - val_loss: 10.5073 - val_acc: 0.0000e+00
# Epoch 3/50
#  - 0s - loss: 12.3385 - acc: 0.1011 - val_loss: 10.5051 - val_acc: 0.2500
# Epoch 4/50
#  - 0s - loss: 12.3395 - acc: 0.1250 - val_loss: 10.4865 - val_acc: 0.2500
# Epoch 5/50
#  - 0s - loss: 12.3257 - acc: 0.1152 - val_loss: 10.4708 - val_acc: 0.2500
# Epoch 6/50
#  - 0s - loss: 12.3099 - acc: 0.1166 - val_loss: 10.4552 - val_acc: 0.2500
# Epoch 7/50
#  - 0s - loss: 12.3067 - acc: 0.1320 - val_loss: 10.4513 - val_acc: 0.2500
# Epoch 8/50
#  - 0s - loss: 12.3280 - acc: 0.1264 - val_loss: 10.4374 - val_acc: 0.1250
# Epoch 9/50
#  - 0s - loss: 12.2951 - acc: 0.1278 - val_loss: 10.4476 - val_acc: 0.2500
# Epoch 10/50
#  - 0s - loss: 12.2906 - acc: 0.1334 - val_loss: 10.4440 - val_acc: 0.2500
# Epoch 11/50
# ...
